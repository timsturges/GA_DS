# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %matplotlib inline
plt.style.use('fivethirtyeight')

df = pd.read_csv('../data/bikeshare.csv',
                 index_col = 'datetime',
                 parse_dates= True)

# %%
df.head()
# Out:
#                      season  holiday  workingday      weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00  Spring        0           0  Clear Skies  9.84  14.395
# 2011-01-01 01:00:00  Spring        0           0  Clear Skies  9.02  13.635
# 2011-01-01 02:00:00  Spring        0           0  Clear Skies  9.02  13.635
# 2011-01-01 03:00:00  Spring        0           0  Clear Skies  9.84  14.395
# 2011-01-01 04:00:00  Spring        0           0  Clear Skies  9.84  14.395
#
#                      humidity  windspeed  count
# datetime
# 2011-01-01 00:00:00        81        0.0     16
# 2011-01-01 01:00:00        80        0.0     40
# 2011-01-01 02:00:00        80        0.0     32
# 2011-01-01 03:00:00        75        0.0     13
# 2011-01-01 04:00:00        75        0.0      1

# %%
weather_map = {'Clear Skies':4,
               'Partly Cloudy':3,
               'Light Storms/Rain':2,
               'Heavy Storms/Rain':1}

df['weather'] = df['weather'].map(weather_map)

# %%
pd.get_dummies(df['season'],
               drop_first = True).head()
# Out:
#                      Spring  Summer  Winter
# datetime
# 2011-01-01 00:00:00       1       0       0
# 2011-01-01 01:00:00       1       0       0
# 2011-01-01 02:00:00       1       0       0
# 2011-01-01 03:00:00       1       0       0
# 2011-01-01 04:00:00       1       0       0

# %%
df = pd.get_dummies(df,
                    drop_first = True)
df.head()
# Out:
#                      holiday  workingday  weather  temp   atemp  humidity  \
# datetime
# 2011-01-01 00:00:00        0           0        4  9.84  14.395        81
# 2011-01-01 01:00:00        0           0        4  9.02  13.635        80
# 2011-01-01 02:00:00        0           0        4  9.02  13.635        80
# 2011-01-01 03:00:00        0           0        4  9.84  14.395        75
# 2011-01-01 04:00:00        0           0        4  9.84  14.395        75
#
#                      windspeed  count  season_Spring  season_Summer  \
# datetime
# 2011-01-01 00:00:00        0.0     16              1              0
# 2011-01-01 01:00:00        0.0     40              1              0
# 2011-01-01 02:00:00        0.0     32              1              0
# 2011-01-01 03:00:00        0.0     13              1              0
# 2011-01-01 04:00:00        0.0      1              1              0
#
#                      season_Winter
# datetime
# 2011-01-01 00:00:00              0
# 2011-01-01 01:00:00              0
# 2011-01-01 02:00:00              0
# 2011-01-01 03:00:00              0
# 2011-01-01 04:00:00              0

# %%
df['temp'] = (df['temp'] - df['temp'].mean()) / df['temp'].std()
df['atemp'] = (df['atemp'] - df['atemp'].mean()) / df['atemp'].std()
df['humidity'] = (df['humidity'] - df['humidity'].mean()) / df['humidity'].std()
df['windspeed'] = (df['windspeed'] - df['windspeed'].mean()) / df['windspeed'].std()

# %%
features_some = ['temp',
                 'atemp',
                 'weather',
                 'humidity']

# %%
features_all = ['holiday',
                'workingday',
                'weather',
                'temp',
                'atemp',
                'humidity',
                'windspeed',
                'season_Spring',
                'season_Summer',
                'season_Winter']

# %%
X_some = df[features_some]
X_all = df[features_all]
y = df['count']

# %%
lr = LinearRegression()

# %%
lr.fit(X_some, y)
print(lr.score(X_some, y))
print(list(zip(features_some,lr.coef_)))
# Out:
# 0.24307517355292274
# [('temp', 23.167142726257005), ('atemp', 45.5475191985618), ('weather', -4.591984143850331), ('humidity', -55.18486553237941)]

# %%
lr.fit(X_all, y)
print(lr.score(X_all, y))
print(list(zip(features_all, lr.coef_)))
# Out:
# 0.2752503232099429
# [('holiday', -8.630472341320143), ('workingday', -2.861549482797657), ('weather', -2.6516939362713394), ('temp', 62.03831630929894), ('atemp', 24.652283817352092), ('humidity', -54.257685839318555), ('windspeed', 4.420026574191246), ('season_Spring', 37.770716087580034), ('season_Summer', 34.97948628938873), ('season_Winter', 102.9792029705163)]

# %%
# alt, quick implementation:
#############################
X = df.loc[:, df.columns != 'count']
y = df['count']

# weather_map = {'Clear Skies':4,
#                'Partly Cloudy':3,
#                'Light Storms/Rain':2,
#                'Heavy Storms/Rain':1}

# df['weather'] = df['weather'].map(weather_map)

num_cols = X.select_dtypes(include=np.number).columns.tolist()
X_std = (X[num_cols] - X[num_cols].mean()) / X[num_cols].std()

# %%
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
coeffs = pd.DataFrame({
    'Vars': X_std.columns,
    'Weight': lr.coef_
}).sort_values(by='Weight', ascending=False)
coeffs
# Out:
#             Vars      Weight
# 9  season_Winter  102.979203
# 3           temp   62.038316
# 7  season_Spring   37.770716
# 8  season_Summer   34.979486
# 4          atemp   24.652284
# 6      windspeed    4.420027
# 2        weather   -2.651694
# 1     workingday   -2.861549
# 0        holiday   -8.630472
# 5       humidity  -54.257686

# %%
mod = sm.OLS(y, X)
results = mod.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     2030.
# Date:                Wed, 31 Jul 2019   Prob (F-statistic):               0.00
# Time:                        21:05:27   Log-Likelihood:                -70401.
# No. Observations:               10886   AIC:                         1.408e+05
# Df Residuals:                   10876   BIC:                         1.409e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# holiday           2.0266      9.246      0.219      0.826     -16.096      20.150
# workingday        8.2734      3.229      2.562      0.010       1.945      14.602
# weather          31.9701      1.128     28.351      0.000      29.760      34.181
# temp             84.0744      9.374      8.969      0.000      65.700     102.448
# atemp            13.6727      9.031      1.514      0.130      -4.031      31.376
# humidity        -42.1665      1.619    -26.041      0.000     -45.341     -38.992
# windspeed         6.4427      1.633      3.946      0.000       3.242       9.643
# season_Spring    79.3370      6.365     12.464      0.000      66.860      91.814
# season_Summer    59.5818      4.453     13.379      0.000      50.852      68.311
# season_Winter   134.8750      5.385     25.046      0.000     124.319     145.431
# ==============================================================================
# Omnibus:                     1997.158   Durbin-Watson:                   0.437
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3709.610
# Skew:                           1.145   Prob(JB):                         0.00
# Kurtosis:                       4.712   Cond. No.                         32.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['hour'] = df.index.hour

# %%
df
# Out:
#                      holiday  workingday  weather      temp     atemp  \
# datetime
# 2011-01-01 00:00:00        0           0        4 -1.333599 -1.092687
# 2011-01-01 01:00:00        0           0        4 -1.438841 -1.182367
# 2011-01-01 02:00:00        0           0        4 -1.438841 -1.182367
# 2011-01-01 03:00:00        0           0        4 -1.333599 -1.092687
# 2011-01-01 04:00:00        0           0        4 -1.333599 -1.092687
# 2012-12-18 22:00:00              1    22
# 2012-12-18 23:00:00              1    23
# 2012-12-19 00:00:00              1     0
# 2012-12-19 01:00:00              1     1
# 2012-12-19 02:00:00              1     2
# 2012-12-19 03:00:00              1     3
# 2012-12-19 04:00:00              1     4
# 2012-12-19 05:00:00              1     5
# 2012-12-19 06:00:00              1     6
# 2012-12-19 07:00:00              1     7
# 2012-12-19 08:00:00              1     8
# 2012-12-19 09:00:00              1     9
# 2012-12-19 10:00:00              1    10
# 2012-12-19 11:00:00              1    11
# 2012-12-19 12:00:00              1    12
# 2012-12-19 13:00:00              1    13
# 2012-12-19 14:00:00              1    14
# 2012-12-19 15:00:00              1    15
# 2012-12-19 16:00:00              1    16
# 2012-12-19 17:00:00              1    17
# 2012-12-19 18:00:00              1    18
# 2012-12-19 19:00:00              1    19
# 2012-12-19 20:00:00              1    20
# 2012-12-19 21:00:00              1    21
# 2012-12-19 22:00:00              1    22
# 2012-12-19 23:00:00              1    23
#
# [10886 rows x 12 columns]

# %%
prices = pd.read_csv('../data/sac_re_cat.csv',
                     index_col = 'sale_date')

# %%
prices.head()

# %%
prices.info()

# %%
prices['zip'] = prices['zip'].astype('category')

# %%
transformed = prices.groupby('zip')['zip'].transform('count')

# %%
prices['zip'] = np.where(transformed < 25,
                         'Other',
                         prices['zip'])

# %%
prices['zip'].value_counts()

# %%
prices.loc[prices['sq__ft'] < 0, 'sq__ft'] = prices.loc[prices['sq__ft'] < 0, 'sq__ft'] * -1

# %%
prices.loc[prices['price'] < 0, 'price'] = prices.loc[prices['price'] < 0, 'price'] * - 1

# %%
prices = prices[(prices['sq__ft'] > 0)
               & (prices['baths'] > 0)
               & (prices['beds'] > 0)]

# %%
prices.head()

# %%
transformed_city = prices.groupby('city')['city'].transform('count')

# %%
prices['city'] = np.where(transformed_city < 25,
                         'OtherC',
                          prices['city'])

# %%
prices['city'].value_counts()

# %%
prices['state'].value_counts()

# %%
pd.get_dummies(prices.drop(['state','street'], axis = 1),
               drop_first = True)

# %%
prices = pd.get_dummies(prices.drop(['state','street'], axis = 1),
                        drop_first = True)
prices.head()

# %%
X_p = prices.loc[:, prices.columns != 'price']
y_p = prices['price']


num_cols = X_p.select_dtypes(include=np.number).columns.tolist()
X_p_std = (X_p[num_cols] - X_p[num_cols].mean()) / X_p[num_cols].std()

# %%
lr.fit(X_p, y_p)

# %%
lr.score(X_p, y_p)

# %%
mod = sm.OLS(y_p, X_p)
results_p = mod.fit()
print(results_p.summary())

# %%
prices['prediction']  = lr.predict(X_p)

# %%
mae = np.mean(np.abs(prices['price'] - prices['prediction']))

# %%
mae

# %%
mse = np.mean((prices['price'] - prices['prediction'])**2)

# %%
mse

# %%
print('MAE:', metrics.mean_absolute_error(prices['price'], prices['prediction']))
print('MSE:', metrics.mean_squared_error(prices['price'], prices['prediction']))
